# %% [markdown]
# # *Utilisation du Mongo Shell* #

# %% [markdown]
# ## *1) Fichiers installés et Ouverture* ##

# %% [markdown]
# *Après installation, on peut retrouver **mongo.exe** qui est MongoDB en ligne de commande et **mongod.exe** aussi appelé "Mongo Daemon" qui execute en arrière plan les tâches de MongoDB comme l'acceptation des requêtes, répondre au client, gérer la mémoire.*

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_16.png")

# %% [markdown]
# *Il peut être utile de créer une nouvelle variable d'environnement vers le dossier bin. Ce qui me permet d'ouvrir le Shell sans indiquer le chemin du dossier.*

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_14.png")

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_15.png")

# %% [markdown]
# *A l'ouverture de MongoDB Shell sur mon terminal préféré, on peut observer la connexion automatique à un serveur local et un id de session*

# %% [markdown]
# ## *2) Commandes de Création de base, Insertion de données et Vérifications* ##

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_17.png")

# %% [markdown]
# *use = créer une database
# db1 = nommage de la database*
#
# *On insert un premier document avec la commande insert et qui a pour clé ou nom "x" dont la valeur est 1. Ce qui crée automatiquement la collection nommée "Col1".*

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_18.png")

# %% [markdown]
# *Ci-dessus, j'ai inséré des données dans une nouvelle collection "Cinema" dans ma database "db". On peut remarquer ici la synthaxe JSON, en paires clé-valeur, qui justifie son utilisation dans les bases de données NoSQL, organisées elles-même en paires clé-valeur.*
#
# *La commande **show dbs** affiche les databases de mon serveur. La commande **show collections** affiche les collections de la database sur laquelle je me trouve actuellement et la commande **db.Cinema.find()** ,ici sans restriction permet de trouver certains documents en spécifiant les attributs à afficher et rechercher.*

# %%
from IPython.display import Image
Image("C:/Users/utilisateur/simplon/dev-data/Briefs/15-SpinOff3/movies-spinoff-mongodb/IMG/Screenshot_19.png")

# %% [markdown]
# *Par défault, voilà ou sont stockées les données*
